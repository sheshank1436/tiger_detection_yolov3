# %% [markdown]
# <a href="https://colab.research.google.com/github/sheshank1436/tiger_detection_yolov3/blob/main/tiger_yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'     pdf     yolo2	     YOLOV3_weights
#  darknet-master.zip   yolo    yolov3	     YOLOV4__weights
# 'My Drive'	      yolo1   yolov3-tiger

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14691, done.
# remote: Total 14691 (delta 0), reused 0 (delta 0), pack-reused 14691
# Receiving objects: 100% (14691/14691), 13.24 MiB | 24.61 MiB/s, done.
# Resolving deltas: 100% (10000/10000), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !echo "tiger" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3-tiger' > data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-01-29 06:08:39--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  2.43MB/s    in 3m 41s
#
# 2021-01-29 06:12:21 (717 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !unzip /mydrive/yolov3-tiger/images1.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3-tiger/images1.zip
#    creating: data/obj/images/
#   inflating: data/obj/images/tiger0.jpg
#   inflating: data/obj/images/tiger0.txt
#   inflating: data/obj/images/tiger1.jpg
#  extracting: data/obj/images/tiger1.txt
#   inflating: data/obj/images/tiger10.jpg
#   inflating: data/obj/images/tiger10.txt
#   inflating: data/obj/images/tiger100.jpg
#   inflating: data/obj/images/tiger100.txt
#   inflating: data/obj/images/tiger101.jpg
#   inflating: data/obj/images/tiger101.txt
#   inflating: data/obj/images/tiger102.jpg
#   inflating: data/obj/images/tiger102.txt
#   inflating: data/obj/images/tiger103.jpg
#   inflating: data/obj/images/tiger103.txt
#   inflating: data/obj/images/tiger104.jpg
#   inflating: data/obj/images/tiger104.txt
#   inflating: data/obj/images/tiger105.jpg
#   inflating: data/obj/images/tiger105.txt
#   inflating: data/obj/images/tiger106.jpg
#   inflating: data/obj/images/tiger106.txt
#   inflating: data/obj/images/tiger107.jpg
# ...

# %%
import os
import glob
print(os.getcwd())
txt_file_paths = glob.glob(r"/content/darknet/data/obj/images/*.txt")
(txt_file_paths)
# Out:
# /content/darknet
# ['/content/darknet/data/obj/images/tiger38.txt',
#  '/content/darknet/data/obj/images/tiger165.txt',
#  '/content/darknet/data/obj/images/tiger79.txt',
#  '/content/darknet/data/obj/images/tiger206.txt',
#  '/content/darknet/data/obj/images/tiger155.txt',
#  '/content/darknet/data/obj/images/tiger169.txt',
#  '/content/darknet/data/obj/images/tiger125.txt',
#  '/content/darknet/data/obj/images/tiger175.txt',
#  '/content/darknet/data/obj/images/tiger71.txt',
#  '/content/darknet/data/obj/images/tiger78.txt',
#  '/content/darknet/data/obj/images/tiger143.txt',
#  '/content/darknet/data/obj/images/tiger210.txt',
#  '/content/darknet/data/obj/images/tiger24.txt',
#  '/content/darknet/data/obj/images/tiger57.txt',
#  '/content/darknet/data/obj/images/tiger183.txt',
#  '/content/darknet/data/obj/images/tiger174.txt',
#  '/content/darknet/data/obj/images/tiger16.txt',
#  '/content/darknet/data/obj/images/tiger139.txt',
#  '/content/darknet/data/obj/images/tiger148.txt',
# ...

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"/content/darknet/data/obj/images/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)
# Out:
# 15 0.352113 0.494350 0.633803 0.807910
#
# ['15', '0.352113', '0.494350', '0.633803', '0.807910']
# 0 /content/darknet/data/obj/images/tiger38.txt
# 0 0.352113 0.494350 0.633803 0.807910
# 15 0.505000 0.484921 0.240000 0.284127
#
# ['15', '0.505000', '0.484921', '0.240000', '0.284127']
# 1 /content/darknet/data/obj/images/tiger165.txt
# 0 0.505000 0.484921 0.240000 0.284127
# 15 0.498239 0.519774 0.869718 0.587571
#
# ['15', '0.498239', '0.519774', '0.869718', '0.587571']
# 2 /content/darknet/data/obj/images/tiger79.txt
# 0 0.498239 0.519774 0.869718 0.587571
# 15 0.693846 0.411250 0.596923 0.762500
#
# ['15', '0.693846', '0.411250', '0.596923', '0.762500']
# 3 /content/darknet/data/obj/images/tiger206.txt
# 0 0.693846 0.411250 0.596923 0.762500
# 15 0.596990 0.407738 0.658863 0.755952
#
# ['15', '0.596990', '0.407738', '0.658863', '0.755952']
# 4 /content/darknet/data/obj/images/tiger155.txt
# 0 0.596990 0.407738 0.658863 0.755952
# 15 0.365625 0.601389 0.378125 0.566667
#
# ...

# %%
import glob
images_list = glob.glob("/content/darknet/data/obj/images/*.jpg")
print(images_list)
# Out:
# ['/content/darknet/data/obj/images/tiger127.jpg', '/content/darknet/data/obj/images/tiger35.jpg', '/content/darknet/data/obj/images/tiger81.jpg', '/content/darknet/data/obj/images/tiger132.jpg', '/content/darknet/data/obj/images/tiger64.jpg', '/content/darknet/data/obj/images/tiger52.jpg', '/content/darknet/data/obj/images/tiger148.jpg', '/content/darknet/data/obj/images/tiger193.jpg', '/content/darknet/data/obj/images/tiger159.jpg', '/content/darknet/data/obj/images/tiger102.jpg', '/content/darknet/data/obj/images/tiger128.jpg', '/content/darknet/data/obj/images/tiger205.jpg', '/content/darknet/data/obj/images/tiger36.jpg', '/content/darknet/data/obj/images/tiger20.jpg', '/content/darknet/data/obj/images/tiger49.jpg', '/content/darknet/data/obj/images/tiger8.jpg', '/content/darknet/data/obj/images/tiger56.jpg', '/content/darknet/data/obj/images/tiger66.jpg', '/content/darknet/data/obj/images/tiger48.jpg', '/content/darknet/data/obj/images/tiger47.jpg', '/content/darknet/data/obj/ima
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# !cp /content/gdrive/MyDrive/yolov3-tiger/yolov3-custom.cfg -d cfg

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3-tiny-custom.cfg  darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
#  total_bbox = 118312, rewritten_bbox = 0.140307 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.538248), count: 1, class_loss = 0.899564, iou_loss = 0.963866, total_loss = 1.863429
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000120, iou_loss = 0.000000, total_loss = 0.000120
#  total_bbox = 118313, rewritten_bbox = 0.140306 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.639374), count: 1, class_loss = 0.946055, iou_loss = 0.238666, total_loss = 1.184721
# ...
